# %%
A = input()
B = input()
if len(A) > len(B):
  print(A)
else:
  print(B)
# Out:
# ttttiiiimmmmeeee
# time
# ttttiiiimmmmeeee

# %%
import math
N = int(input())
A=list(map(int,input().split()))
if (0 in A) == True:
  A.remove(0)
answer = sum(A)/len(A)
print(math.ceil(answer))
# Out:
# 5
# 1 4 9 10 15
# 8
