# %%
X = input()
print(ord(X)-ord('A')+1)
# Out:
# E
# 5

# %%
a = int(input())
b = int(input())

if abs(a-b) > ((10-a)+b):
  print((10-a)+b)
elif abs(a-b) > ((10-b)+a):
  print((10-b)+a)
else:
  print(abs(a-b))
# Out:
# 8
# 1
# 3

# %%
N,H = map(int,input().split())
A,B,C,D,E = map(int,input().split())

if B/A > D/C:
  
for i in range(N):
  if H <= 0:
