# %%
N = int(input())
if N%3 == 0:
  print('YES')
else:
  print('NO')

# %%
n = int(input())
a = 0
b = 0
c = 1
if n < 3:
  print("0")
elif n >= 3:
  for i in range(2,n-1):
    temp = a
    a = b
    b = c
    c = temp + a + b
    # 計算途中で剰余を用いることにより計算を速くする！
    if a > 10007:
      a = a%10007
      b = b%10007
      c = c%10007
  print(c%10007)
# n = int(input())
# an = list((0,0,1))
# if n < 3:
#   print("0")
# elif n >= 3:
#   for i in range(2,n-1):
#     an.append(an[i]+an[i-1]+an[i-2])
#   print(an[n-1]%10007)
# Out:
# 100000
# 100000
# 7927

# %%
N,M = map(int, input().split())
odd = 0
for i in range(N*4):
  print(i+1)
  print(M)
  if M%2 == 1:
    M=M-1
    odd = 1
  if M/2 == 1:
    break
  M = M/2

i = i+1
if odd == 1:
  i = i-1
  j = 1
print(i,j,0)
# Out:
# 7 23
# 1
# 23
# 2
# 11.0
# 3
# 5.0
# 4
# 2.0
# 3 1 0
