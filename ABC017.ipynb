# %%
s1,e1 = map(int, input().split())
s2,e2 = map(int, input().split())
s3,e3 = map(int, input().split())

print(int(s1*e1*0.1+s2*e2*0.1+s3*e3*0.1))

# %%
X = input()
isChoku = False
for i in range(len(X)):
  if X[0] == 'o' or X[0] == 'k' or X[0] == 'u':
    X = X[1:]
    continue
  elif X[0] == 'c' and X[1] == 'h':
    X = X[2:]
    continue
  print('end')
print(X)
# Out:
# ch
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-5ebb1c884862> in <module>()
#       2 isChoku = False
#       3 for i in range(len(X)):
# ----> 4   if X[0] == 'o' or X[0] == 'k' or X[0] == 'u':
#       5     X = X[1:]
#       6     continue
#
# IndexError: string index out of range
